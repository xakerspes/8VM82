# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import Image

# %matplotlib inline

# %%
data=np.loadtxt('data.dat')
sst = data
n=len(sst)
dt = 0.25 
fig = plt.figure(figsize=(20, 10))
time = np.arange(n) # Дни 365
xlim = [-20,385]  # Масштаб
plt.plot(time,sst)
xrange=plt.xlim(xlim)
plt.title('Исходный график 2017-2018', fontsize=30)
# Out:
# Text(0.5,1,'Исходный график 2017-2018')

# %%
width= 0.65
hight = 0.28;
pos1a = [0.1, 0.75, width, 0.2]
pos1b = [0.1, 0.37, width, hight]
pos1c = [0.79, 0.37, 0.18, hight]
pos1d = [0.1,  0.07, width, 0.2]

fig = plt.figure(figsize=(15, 6))
ax = fig.add_subplot(111)

xtime= np.linspace(0,364,365)
data = data.reshape((365))

ax.plot(xtime, data, 'black', alpha=1.00, linewidth=2)
ax.fill_between(xtime, 0., data, data> 0., color='red', alpha=.75)
ax.fill_between(xtime, 0., data, data< 0., color='blue',  alpha=.75)

plt.xlabel('Дни', fontsize=15)
plt.ylabel('$^oC$', fontsize=15)
plt.title('Температура за 2017 - 2018', fontsize=25)

ax.set_xlim(-20, 385)
ax.set_ylim(-40, 40)


plt.grid(True)
ax.autoscale_view()

# %%
#figure size
fig = plt.figure(figsize=(25, 25))
variance = np.std(sst)**2
mean=np.mean(sst)
sst = (sst - np.mean(sst))/np.sqrt(variance)
#Добавляем точки на исходный график 
ax=fig.add_axes(pos1a)
#original
ax.plot(time,sst*np.sqrt(variance)+mean,"r-")
#reconstruction
ax.plot(time,sst*np.sqrt(variance)+mean,"x--")
ax.set_xlabel('Дни',fontsize=20)
ax.set_ylabel('(degC)',fontsize=20)
plt.title('Температура', fontsize=30)
# Out:
# Text(0.5,1,'Температура')

# %%
Image(filename='wavelet.png')

# %%
from scipy import signal
import matplotlib.pyplot as plt
widths = np.arange(1, 61)
cwtmatr = signal.cwt(sst, signal.ricker, widths)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\mkl_fft\_numpy_fft.py:1044: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   output = mkl_fft.rfftn_numpy(a, s, axes)

# %%
fig = plt.figure(figsize=(18, 10))
ax.set_xlabel('(degC)')
plt.plot(cwtmatr[0])
plt.plot(cwtmatr[1])
plt.plot(cwtmatr[2])
plt.plot(cwtmatr[3])
plt.xlabel('Дни', fontsize=20)
plt.ylabel('Амплитуда', fontsize=20)
plt.title('Рассчитанные значения интегралов функции для каждого масштаба в каждый момент времени', fontsize=20)
# Out:
# Text(0.5,1,'Рассчитанные значения интегралов функции для каждого масштаба в каждый момент времени')

# %%
fig = plt.figure(figsize=(20, 10))
plt.title('Вейвлет преобразование Мексиканская шляпа', fontsize=30)
plt.imshow(cwtmatr, extent=[-1, 365,-1,1], cmap='PRGn', aspect='auto', vmax=abs(cwtmatr).max(), vmin=-abs(cwtmatr).max())
plt.xlabel('Дни', fontsize=20)
plt.ylabel('Амплитуда', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(25,15))
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(0,365,365)
y = np.arange(60)
X,Y = np.meshgrid(x,y)
Z = np.zeros((len(y),len(x)))


for i in range(len(y)):
    Z[i] = cwtmatr[i]

ax.plot_surface(X, Y, Z, rstride=1, cstride=5, cmap='seismic',
                        alpha=1,
                        linewidth=0,
                        antialiased=True, shade=False, lw=20)
plt.title('Вейвлет преобразование Мексиканская шляпа', fontsize=30)
ax.set_zlabel("Амплитуда", fontsize=20)
ax.set_xlabel("Дни", fontsize=20)
ax.set_ylabel("Масштаб", fontsize=20)
ax.view_init(20,-120)
plt.show()

# %%
widths = np.arange(1, 41)
cwtmatr = signal.cwt(sst, signal.gaussian, widths)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\mkl_fft\_numpy_fft.py:1044: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   output = mkl_fft.rfftn_numpy(a, s, axes)

# %%
fig = plt.figure(figsize=(18, 10))
ax.set_xlabel('(degC)')
plt.plot(cwtmatr[0])
plt.plot(cwtmatr[1])
plt.plot(cwtmatr[2])
plt.plot(cwtmatr[3])
plt.plot(cwtmatr[4])
plt.plot(cwtmatr[5])
plt.plot(cwtmatr[6])
plt.plot(cwtmatr[7])
plt.xlabel('Дни', fontsize=20)
plt.ylabel('Амплитуда', fontsize=20)
plt.title('Рассчитанные значения интегралов функции для каждого масштаба в каждый момент времени', fontsize=20)
# Out:
# Text(0.5,1,'Рассчитанные значения интегралов функции для каждого масштаба в каждый момент времени')

# %%
fig = plt.figure(figsize=(20, 10))
plt.title('Вейвлет преобразование Морлет', fontsize=30)
plt.imshow(cwtmatr, extent=[-1, 365,-1,1], cmap='PRGn', aspect='auto', vmax=abs(cwtmatr).max(), vmin=-abs(cwtmatr).max())
plt.xlabel('Дни', fontsize=20)
plt.ylabel('Амплитуда', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(25,15))
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(0,365,365)
y = np.arange(40)
X,Y = np.meshgrid(x,y)
Z = np.zeros((len(y),len(x)))


for i in range(len(y)):
    Z[i] = cwtmatr[i]

ax.plot_surface(X, Y, Z, rstride=1, cstride=5, cmap='seismic',
                        alpha=1,
                        linewidth=0,
                        antialiased=True, shade=False, lw=20)
plt.title('Вейвлет преобразование Морлет', fontsize=30)
ax.set_zlabel("Амплитуда", fontsize=20)
ax.set_xlabel("Дни", fontsize=20)
ax.set_ylabel("Масштаб", fontsize=20)
ax.view_init(20,-120)
plt.show()

# %%
fig = plt.figure(figsize=(18, 10))
ax.set_xlabel('(degC)')
plt.plot(cwtmatr[0])
plt.plot(cwtmatr[1])
plt.plot(cwtmatr[2])
plt.plot(cwtmatr[3])
plt.plot(cwtmatr[4])
plt.plot(cwtmatr[5])
plt.plot(cwtmatr[6])
plt.plot(cwtmatr[7])
plt.xlabel('Дни', fontsize=20)
plt.ylabel('Амплитуда', fontsize=20)
plt.title('Рассчитанные значения интегралов функции для каждого масштаба в каждый момент времени', fontsize=20)
# Out:
# Text(0.5,1,'Рассчитанные значения интегралов функции для каждого масштаба в каждый момент времени')
